# %%
import pandas as pd #자료의 데이터프레임화
import random #타임슬립에 랜덤숫자적용
import time #타입슬립
import json #파일저장
#인스타그램 접속
from random_user_agent.params import SoftwareName, OperatingSystem 
from random_user_agent.user_agent import UserAgent
#웹드라이버 및 화면조종
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.common.by import By #로딩함수에 적용
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys

# from eunjeon import Mecab
import unicodedata #이모티콘
# import pyodbc
import re #문자분류
import collections 
class IG_Bot:
    '''로봇처럼 보이기 방지'''
    
    def __init__(self, username, password):
        software_names= [SoftwareName.CHROME.value]
        operating_systems=[OperatingSystem.WINDOWS.value]
        
        #Randomized User ID
        user_agent_rotator= UserAgent(software_name = software_names,
                                     operating_systems=operating_systems,
                                     limit=100)
        user_agent= user_agent_rotator.get_random_user_agent()
        chrome_options=Options()
#         chrome_options.add_argument("--headless")
        chrome_options.add_argument("--no-sendbox")
        chrome_options.add_argument("--disable-gpu")
        chrome_options.add_argument(f'user-agent={user_agent}')
        path='c:\python_temp\chromedriver.exe'
        
        cookies_file_path='c:\IG\cookies.json'
        cookie_websites=['https://instagram.com']
        self.cookies_file_path= cookies_file_path
        self.cookie_websites= cookie_websites
        self.driver=webdriver.Chrome(chrome_options=chrome_options,executable_path=path)
        
        self.driver.get('https://instagram.com')
        
        time.sleep(1.5)

        try:
            cookies=json.load(open(self.cookies_file_path,'rb'))
            for website in self.cookie_websites:
                for cookie in cookies:
                    self.driver.add_cookie(cookie)
                self.driver.refresh()
        except Exception as e:
            print(str(e))
       
    def loading(self,xpath):
        '''페이지로딩 기다리기'''
        WebDriverWait(self.driver,60).until(EC.presence_of_element_located((By.XPATH,xpath)))
    
    def save_cookies(self):
        '''쿠키저장'''
        json.dump(self.driver.get_cookies(),open('c:\IG\cookies.json','w'))
    
    def load_cookies(self):
        '''쿠키로드'''
        cookies= json.load(open('cookies.json','rb'))
        for cookie in cookies:
            self.driver.add_cookie(cookie)
    
    def login(self):
        '''로그인'''
        try:
            self.driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[1]/div/label/input').send_keys(username)
            self.driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[2]/div/label/input').send_keys(password)
            self.loading('//*[@id="loginForm"]/div/div[3]')
            time.sleep(0.5)
            self.driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[3]').click()
            self.loading('//*[@id="react-root"]/section/main/div/div/div/div/button')
            self.driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/div/div/button').click()
            self.loading('/html/body/div[5]/div/div/div/div[3]/button[2]')
            self.driver.find_element_by_xpath('/html/body/div[5]/div/div/div/div[3]/button[2]').click()
        except:
            self.loading('/html/body/div[5]/div/div/div/div[3]/button[2]')
            self.driver.find_element_by_xpath('/html/body/div[5]/div/div/div/div[3]/button[2]').click()

'''크롤러'''           
class Crawler(IG_Bot):
    global insta_dict
    global number
    ########################################숫자바꾸기#############################################
    number=1
    insta_dict=[]
    


    def run(self):
        continue_=True
        count=0
        query=input('검색어를 입력하시오. > ') 
        query=re.sub('[ ]','', query)
        self.driver.get('https://www.instagram.com/'+query)
        
        s_time=time.time()
        try:
            self.driver.find_element_by_xpath('/html/body/div[5]/div/div/div/div[3]/button[2]').click()
        except:
            pass
        time.sleep(0.5)
        self.loading('//*[@id="react-root"]/section/main/div/div[3]/article/div[1]/div/div[1]/div[1]/a/div[1]/div[2]')
        
        self.driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[3]/article/div[1]/div/div[1]/div[1]/a/div[1]/div[2]').click()
        while count<2000:
            self.crawl()
            
                                                #Acting like person by random
            time.sleep(random.randrange(0,5))
            try:
                self.driver.find_element_by_css_selector('div.l8mY4 ').click()
            
            except:
                continue_=False
            count+=1
            time.sleep(2)
            if continue_==False:
                break
        
        print('id 저장 개수 :{}개'.format(len(insta_dict['id'])))
        print('텍스트 저장 개수 :{}개'.format(len(insta_dict['text'])))

        e_time=time.time()
        (f'{e_time-s_time}초 걸렸습니다.')    
        
            
            
            ###################숫자바꾸기######################
  #페이지 스크랩핑  
    def crawl(self):
        extract={"id": "IPRW21", 
     "metadata": { "title": "휘뚜마뚜 웹문서 말뭉치 IPRW21", 
                  "creator": "이재관", 
                  "distributor": "휘뚜마뚜", 
                  "year": "2021", 
                  "category": "인스타그램 > 식물", 
                  "annotation_level": [ "원시" ], 
                  "sampling": "텍스트 추출" }, 
     "document": {"metadata": { "title": "무제", 
                                 "author": "", 
                                 "date": "20211110" }, 
                    "content": {"text": ""}}
                }
        global number
        self.loading('/html/body/div[6]/div[2]/div/article')
             
            
        ## id 정보 수집
        try:
            info_id = self.driver.find_element_by_css_selector('h2._6lAjh').text
            extract['document']['metadata']['author']=info_id
        except:
            try:          
                info_id = self.driver.find_element_by_css_selector('div.C4VMK').text.split()[0]
                extract['document']['metadata']['author']=info_id
            except:  
                info_id = self.driver.find_element_by_css_selector('div.e1e1d').text
                extract['document']['metadata']['author']=info_id
        ## 시간정보 수집 
        uploadTime=self.driver.find_element_by_css_selector('time._1o9PC')
        time_info=uploadTime.get_attribute('datetime')[:19]
        extract['document']['metadata']['date']=time_info
        ##text 정보수집
        try:
            raw_info = self.driver.find_element_by_css_selector('div.C4VMK').text.split()
            raw_info = raw_info[1:len(raw_info)-1]
            text=[]
            ######################광고나 필요없는 단어 거르기############################
            
            stopword='''🌿 식물구매 및 상담: 카카오톡 @고포레스트
🌿 주소: 서울특별시 서초구 강남대로27#양재꽃시장가동8호
  소망&고포레스트 (첫째주, 셋째주 일요일 휴무)
🌿 서울, 경기, 인천 등 수도권지역은 당일배송도 가능합니다. [🌿고포레스트🌿]
프로필 상단 카톡 id ID 문의 전화 오시는 길 전화번호 주차 DM 댓글
'''
            stopword=stopword.split(' ')
            
            for i in raw_info:
             
                if i in stopword:
                    pass
                else:
                    i=re.sub('[\U00010000-\U0010ffff#@&*^%$!~-[]+={};:]',' ',i)
                    
                    if i=='':
                        pass
                    else:
                     
                        text.append(i)
            clean_text = ' '.join(text)
            extract['document']['content']['text']=clean_text
        except:
            text=''
            
        
    #일련번호
        if clean_text=='':
            pass
        else:
            s_number=str(number).zfill(8)
            extract['id']=extract['id'][:6]+s_number
            number+=1

            #insta_dict
            insta_dict.append(extract)
        
        '''c드라이브에 IG폴더 만들고 secret.txt 파일에 윗줄에 아이디 2번째줄에 비밀번호 입력'''    
if __name__=='__main__':
    "Main (runs through classes)"
    data=pd.read_csv('c:\IG\secret.txt',header=None)
    username=data.iloc[0][0]
    password=data.iloc[1][0]
    
    '''처음실행하고 쿠키저장'''
def first_login():     
    '''Check login to instagram and save cookies'''
    bot=IG_Bot(username,password)
    bot.login()
    bot.save_cookies()

    '''쿠키저장 후 크롤러 가동하기'''
def run_():
    # '''Crawler'''
    bot=Crawler(username,password)
    bot.run()
# first_login()
run_()

'''아래 셀은 쿠기 저장 예시'''
# Out:
# <ipython-input-11-9217a16cae60>:46: DeprecationWarning: use options instead of chrome_options
#   self.driver=webdriver.Chrome(chrome_options=chrome_options,executable_path=path)
# 검색어를 입력하시오. > goforest.365
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9217a16cae60> in <module>
#     234     bot.run()
#     235 # first_login()
# --> 236 run_()
#     237
#     238 '''아래 셀은 쿠기 저장 예시'''
#
# <ipython-input-11-9217a16cae60> in run_()
#     232     # '''Crawler'''
#     233     bot=Crawler(username,password)
# --> 234     bot.run()
#     235 # first_login()
#     236 run_()
#
# <ipython-input-11-9217a16cae60> in run(self)
#     130                 break
#     131
# --> 132         print('id 저장 개수 :{}개'.format(len(insta_dict['id'])))
#     133         print('텍스트 저장 개수 :{}개'.format(len(insta_dict['text'])))
#     134
#
# TypeError: list indices must be integers or slices, not str

# %%
insta_dict
# Out:
# [{'id': 'IPRW2100000001',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2021-11-16T08:50:18'},
#    'content': {'text': '[ 고포레스트 ]  휘카스  휘카스움베르타  Ficusumbellata⠀⠀⠀⠀⠀ 잎이 크고 멋있는 휘카스 움베르타. 공기 정화 능력이 탁월하고 산소를 많이 배출하며 담배 냄새까지 흡수한다고 알려져 있는데요. 커다란 초록 잎이 올곧게 뻗은 휘카스 움베르타 참 매력적이에요     휘카스움베르타키우기 Tip   햇빛은 직사광선을 피한 통풍이 잘되고 양지, 반양지에서 키워주세요. ⠀ 직광에서는 잎이 주름지고 탈 수 있습니다. ⠀ 봄부터 가을까지 성장이 활발하고 겨울에는 휴면한답니다. ⠀⠀  물은 흙이 손가락 반마디깊이정도 마르면 화분 밑으로 관수될 정도로 충분히 주세요. 물이 부족하거나 너무 많이 주는 경우에는 잎이 노랗게 변하면서 떨어집니다. 건조한 환경에서는 응애가 생기기 쉬우니 습도가 낮아지면 잎에 물을 자주 분무해주세요   고포레스트 강남대로27 양재꽃시장가동8호 휴무)'}}},
#  {'id': 'IPRW2100000002',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2021-11-16T08:41:11'},
#    'content': {'text': '[ 고포레스트 ]  마지나타  마지나타레인보우  dracenamarginata marginata⠀⠀⠀⠀⠀ 잎 옆선을 따라서 적색의 선이 나있고 늘어지는 모양이 매우 예쁜 마지나타 레인보우. 특히 잎이 가늘고 곁가지가 잘 뻗어서 실내인테리어 식물로 최근 인기가 많은데요 내음력(음지에서 견디는 힘)도 매우 강해서 오랫동안 실내에서 잘 견디며 실내 어느 곳에 놓아도 잘 자랍니다. 키우기도 쉬운편이라  식물초보집사 분들에게 추천드려요    마지나타키우기 Tip  반양지, 반음지에서도 잘자라고  물은 흙이 손가락 반마디깊이정도 확실히 마르면 충분히 주세요 키우시다 잎이 쳐지는 경우가 많으신데 원인으론 햇빛이 부족하거나 물이 부족한 경우가 많으니 상황에 맞게 빛이 더 잘드는곳으로 옮겨주시거나 물주기를 당겨서 주시면 됩니다.  고포레스트 강남대로27 양재꽃시장가동8호 휴무)'}}},
#  {'id': 'IPRW2100

#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2021-08-24T03:14:24'},
#    'content': {'text': '[ 고포레스트 ]  유포르비아 옵투시폴리아⠀⠀⠀⠀⠀⠀  Euphorbiaobtusifolia  희귀선인장 옵투시폴리아 농장에선 유포르비아로만 알고 계셔서 요녀석 이름 찾는데 한참 걸린것같아요. 줄기라인이 참 매력적인데요 선인장이지만 가시가 없고 잎이 나는 선인장입니다. 카나리아제도에 많이 서식하는데 한국에 적은 수량만 수입이 되어 평소에 찾아보기 힘든 수종이랍니다.  햇빛을 좋아하고 건조에 아주 강합니다. 물은 3 4주에 한번 정도 흙이 손가락 두마디깊이 바싹 마르면 주세요. ☠일반적으로 선인장 수액에는 독성이 있는데 요아이도 잎을 따거나 줄기에 상 하얀 수액이 나옵니다. 눈이나 입에 들어가지 않도록 주의하시고 바로 씻어주세요.  고포레스트 강남대로27 양재꽃시장가동8호 휴무)'}}},
#  {'id': 'IPRW2100000041',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2021-08-24T02:17:52'},
#    'content': {'text': '[ 고포레스트 ]⠀ 오렌지자스민  화분포함 110cm 연두빛 푸릇푸릇한 잎도 너무 예쁜 오렌지자스민 일년에 온도가 맞으면 두세번 꽃이 피는데 향기가 참 좋아 인기가 많답니다.⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  오렌지자스민키우기 ⠀⠀⠀⠀ ⠀⠀⠀⠀   햇빛이 잘드는 곳에서 키워주셔야 꽃도 잘 피고 잎이 짱짱하게 나옵니다. ⠀⠀ ⠀⠀  물주기는 겉흙이 전체적으로 확실히 말랐을때 화분밑으로 물이 빠져나올만큼 충분이주세요  ⠀⠀⠀⠀ ⠀⠀⠀⠀  고포레스트 강남대로27 양재꽃시장가동8호 휴무)'}}},
#  {'id': 'IPRW2100000042',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2021-08-20T06:35:17'},
#    'content': {'text': '[ 고포레스트 ]  필로덴드론플로리다뷰티그린  플로리다뷰티그린  floridabeautygreen 강한 생명력으로 반양지, 반음지에서도 잘자라 키우기 쉬운 플로리다 뷰티그린 개성있는 잎과 라인이 매력적이라  인테리어식물 로 사랑받고 있답니다   식물초보  식물킬러 도 문제없어요    인테리어 공간스타일링  studio.acel  고포레스트 강남대로27 양재꽃시장가동8호 휴무)'}}},
#  {'id': 'IPRW2100000043',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2021-08-16T14:49:20'},
#    'content': {'text': '[ 고포레스트 ]  구아바나무  과실수  화분포함 150cm 유니크한 수형의 구아바나무  향기롭고 새콤달콤한 열매는 즙이 많고 달콤하며 비타민을 많이 함유하고 있어 날로 먹거나 통조림·젤리·치즈·잼 등의 원료로 쓰인답니다. 잎은 말려 차로 마시면 당료나 환절기 비염에 아주 좋다고 합니다. 열매부터 잎, 줄기, 뿌리까지 버릴게없는 구아바  ⠀⠀⠀⠀⠀⠀ ⠀⠀⠀ ⠀⠀⠀⠀  구아바키우기 tip  햇빛을 좋아하는 나무라 양지, 반양지에서 키워주세요. ⠀⠀⠀⠀⠀⠀⠀⠀  물주기는 겉흙이 마르면 화분밑으로 물이 나올정도로 듬뿍주세요.  성장기때(봄 여름) 영양제 챙겨주시면 나무도 튼튼해지고 열매도 잘 큰답니다. ⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀  고포레스트 강남대로27 양재꽃시장가동8호 휴무)'}}},
#  {'id': 'IPRW2100000044',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2021-08-16T14:34:22'},
#    'content': {'text': '[ 고포레스트 ]⠀ 무화과나무  과실수  무화과  화분포함 70 80cm ⠀⠀ ⠀⠀⠀ 푸릇푸릇 싱그러운 잎과 동글동글 열매가 매력적인 무화과나무예요   ⠀ 무화과는 환경에따라 연중 열매가 열리는 착한 나무랍니다. (일년에 두번정도 수확가능) ⠀ 키우기가 쉬운편이고 수형도 너무 예뻐 반려식물로 추천드려요 ☺️ ⠀⠀ ⠀  무화과나무키우기 Tip  양지, 반양지에서 키워주시면 좋고  물을 좋아하는 하는 나무라 겉흙이 마르면 주시고 규칙적으로 주시는게 좋습니다. ⠀ ⠀ ⠀ ⠀  고포레스트 강남대로27 양재꽃시장가동8호 휴무)'}}},
#  {'id': 'IPRW2100
재꽃시장가동8호 휴무)'}}},
#  {'id': 'IPRW2100000065',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2021-06-28T11:28:33'},
#    'content': {'text': "[ 고포레스트 ]  극락조  극락조화 '영원불변' 참 꽃말도 멋진 극락조 꽃이 극락조새와 닮아 붙여진 이름인데요 여인초와 혼동하시는 분들이 많답니다.  여인초 보다 잎이 단단하고 뽀족한 모양으로 짙은 녹색을 띈답니다. 공기정화능력도 좋고 키우기 쉬운편이라  식물초보 분들에게 추천드려요   극락조키우기 Tip   직사광선을 피한 밝은 간접광이 비치는 장소가 좋습니다. 통풍이 잘되는 곳이면 좋으나 모든 식물이 그러하듯 에어컨 바람과 온풍기 바람이 직접 닿는 곳은 피해 주는 것이 좋습니다.  물은 흙이 손가락 한마디 깊이정도 확실히 마르면 주시고과습에 유의해주세요   식물사이즈 : 화분포함 150cm ⠀⠀⠀⠀⠀⠀ 식물문의는 카카오톡( 고포레스트) 으로 문의주세요  환경에 맞는 소형 특대형 식물 화기 함께 고민해드립니다. 강남대로27  양재꽃시장가동8호 휴무)"}}},
#  {'id': 'IPRW2100000066',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2021-06-28T05:56:17'},
#    'content': {'text': '[ 고포레스트 ]  휘카스움베르타  휘카스 싱그러운 잎과 깔끔한 라인이 돋보이는 휘카스움베르타   그레이톤으로 깔끔한 화분, 이태리 토분에 식재해봤는 둘다 잘 어울리네요   전체크기는 화분포함 160cm 산소탱크라는 별명만큼 공기정화에도 효과적이고 키우기 쉬운편이라 반려식물로 추천드려요   ⠀⠀ ⠀ ⠀⠀⠀⠀   햇빛은 직사광선을 피한 통풍이 잘되고 양지, 반양지에서 키워주세요. ⠀⠀⠀⠀⠀  물은 흙이 손가락 한마디깊이정도 마르면 화분 밑으로 관수될 정도로 충분히 주세요. ⠀⠀⠀⠀ ⠀⠀⠀⠀ 식물문의는 카카오톡( 고포레스트) 으로 문의주세요  환경에 맞는 소형 특대형 식물 화기 함께 고민해드립니다. 강남대로27  양재꽃시장가동8호 휴무)'}}},
#  {'id': 'IPRW2100000067',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
# ...
#  {'id': 'IPRW2100000288',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-21T05:33:30'},
#    'content': {'text': '[고포레스트] 예쁜 카페  8bdolce 로 분양된 식물들  아티스트와 콜라보레이션으로 미술작품이 전시되고 있었는데 거기에 식물까지 함께하니 너무도 멋있네요  ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000289',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-16T04:30:35'},
#    'content': {'text': '[고포레스트] 오늘의 친구는 새잎을 낸 자이언트  무늬몬스테라 키우기도 쉽고 잎모양이 특이해 정말 많은 분들이 사랑해주고 있는 친구예요. 정식이름은  몬스테라델리시오사바리에가타 75cm 높이의 대형사이즈입니다. 중간에 구멍도 퐁퐁, 새순에는 크림색 무늬가 많이 보이네요  새순이 넘 예뻐 보여드리고 싶었어요    몬스테라에도 여러 종류가 있는데요 비슷하게 생겨 식물판매자분들도 이름을 잘 모르시고 판매하시분들도 많답니다.   ⠀⠀⠀⠀ ⠀⠀⠀⠀  먼저 많이 판매되고 대중적인 몬스테라 두종류 구분 방법을 알려드릴께요  잎사귀와 줄기사이의 프릴(구불구불한모양)이 있다면 (세번째 사진 참고)  델리시오사( monsteradeliciosa), 없다면  보르시지아나( monsteraborsigiana) 입니다. 일반적으로 델리시오사가 보르시지아나 보다 줄기가 굵고 잎이 크게 나는 반면 보르시지아나는 덩굴성이 강하고 잎이 크게 자라지 않아요. ⠀⠀⠀⠀ ⠀⠀⠀⠀ 거기에 무늬가 있다면 이름이 더 길어지는데요 ㅋ  크림색 무늬라면 바리에가타(variegata) ⠀⠀⠀⠀  하얀색 무늬라면 알보(Albo variegata) 라고 붙습니다. ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ 사실 무늬가 있는 부분은 엽록소가 없어 광합성을 못한다고 보시면됩니다. 증산작용 또한 활발하지못해 물을 잘못 주게될 경우 잎이 까맣게 되버려요..   소중한 무늬를 지키고 싶다면    적당량의 햇빛과 과습되지 않도록 통풍이 잘 되는 곳에 키워주세요  ⠀⠀ ⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000290',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-15T13:11:53'},
#    'content': {'text': '[고포레스트]  실물깡패 수형이 너무나 예쁜 2.1 2.3m 대형  퀸즈랜드실버와틀 ⠀⠀⠀⠀ 폭신폭신 보들보들 솜털이 매력포인트  마치 토끼귀를 만지는 기분이 듭답니다. 계속 만지고 싶다는.. ㅋ 은빛으로 빛나 멀리서보면  유칼립투스 같기도하지만 가까이서 보면 잎이 두툼, 전혀다른 느낌을 준답니다.  아카시아 답게 햇빛을 좋아하고 통풍이 잘되는 곳에 키우시면 좋습니다. 물주기가 생각보다 긴편이라 어렵지않게 키울수 있어요   꽃대도 물려있어 곧 노란색꽃을 볼수 있겠네요  넘 기대가 됩니다.   ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000291',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-15T03:56:10'},
#    'content': {'text': '[고포레스트] 오늘의 사랑스러운 쪼꼬미 친구들 소개합니다. 귀하디 귀한  알리고무나무 천사의 날개  미니소철 할로윈 맞이  호박토분 생선뼈 닮은  피쉬본 선인장 동글  오베사 크로버 닮은  멕시코소철 동글동글  필레아페페로미오이데스 ⠀⠀⠀⠀ ⠀⠀⠀⠀ 맛점하시고 날씨도 좋은데 귀요미들 보러 놀러오세요   ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000292',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-15T03:13:18'},
#    'content': {'text': '[고포레스트] 개성넘치는 목대 라인이 매력인 2.8m 대형  드라세나마지나타 ⠀⠀ 대형사이즈부터 소형사이즈까지 공간에 맞게 구매하실 수 있답니다    토분  모던한화분 모두 잘울린답니다. 공기정화도 탁월하고 키우기 쉬운 마지나타  마지나타 잎색상이 다양한데요 정말 매력적이랍니다. 곧 소개해드릴께요   ⠀ ⠀⠀ ⠀⠀⠀⠀ ⠀⠀  마지나타키우기 Tip ⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀   간접광이 들어오는 반음지에서 잘 자랍니다. 여름철 직사광선은 피해주시고 너무 어두운 곳에 키우시면 잎의 붉은 줄무늬 색이 흐려지고 새로 자라는 가지가 가늘게 자라 볼품이 없어질수 있으니 주위해주세요  (월동온도 15도 이상) ⠀⠀⠀⠀  물빠짐이 좋은 화분인경우 겉흙이 확실히 마르면 관수될정도로 듬뿍주세요  물이 모자랄경우 잎이 노랗게 될수 있어요  장마철, 겨울에는 흙 마름상태 체크후 물주는 기간을 평상시보다 길게 늘려주세요. 습한 환경을 좋아하는 식물이지먀 너무 과습되지 않도록 주의해주세요  ⠀⠀⠀⠀ ✂️ 나무가 크다보면 자연스럽게 맨 아래잎들이 노랗게는데 때어내어주심 됩니다. 오랜 기간 키우다보면 영양이나 환경에따라 가지들이 볼품없이 자랐다면 과감히 균형에 맞게 가지치기해주시면 잘린 주변으로 3 4 개씩 새순이 나올꺼예요. ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀'}}},
#  {'id': 'IPRW2100000293',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-14T12:32:03'},
#    'content': {'text': '[고포레스트] 이국적인 은빛의 아름다운 색감과 겨울에도 월동이 가능한  실유카  비욘드블루 ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ 평소 저희 매장 식물을 자주 이용해 주시는 디자인 인테리어 회사에서 사무실 이전을 하셨는데 사무실 앞 작은 화단이 풀만가득해 이국적이고 흔하지 않은 식물로 채우고 싶어하셨어요. ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ 관리가 쉬우면서 사계절 내내 푸른 비욘드블루와 거친듯 하지만 때가되면 어김 없이 꽃을 피워주는 실유카를 식재해드렸답니다.   사계절내내 푸르른 식물들처럼 생기 넘치고 성장하는 회사가 되시길 기원합니다    ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000294',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-13T14:30:11'},
#    'content': {'text': '[고포레스트] 라인이 정말 예뻤던 2.7m 높이의  대형호프셀렘 ❤ 오랫동안 길러 정이 많이 들었는데 멋진분에게 분양되어 가서 넘 기뻤던 기억이 나네요.   특히 공중뿌리(지주근)도 멋있게 나와 튤립모양의  대형토분 과 정말 잘 어울렸답니다.   셀렘은 뛰어난 공기 정화 효과가 있어 실내공기를 쾌적하게 해주는 기능성 식물로 키워도 좋습니다 :) ⠀⠀⠀⠀  식물 초보자들도 쉽게 키울수 있답니다  ⠀⠀ ⠀ ⠀⠀⠀ ⠀⠀ ⠀⠀⠀⠀ 호프셀렘 키우기 Tip ⠀⠀⠀ ⠀⠀ ⠀⠀ ⠀  약간 습하고 햇빛이 적은 반음지에서 잘 적응하는 편입니다  하지만 하루 중 최소 1 2시간은 간접광을 받도록 해야 잎이 튼튼하게 자라요. 단, 직사광선을 받으면 잎이 탈수있으니 주의해주세요   ⠀⠀⠀⠀ ⠀⠀⠀⠀  흙이 건조해도 잘 버티지만 공중습도가 높은 것을 좋아하는 식물입니다 :D 성장이 활발한 더운 여름에는 화분의 겉흙이 확실히 마르면 물을 흠뻑 주세요  이때 물 빠짐이 좋지 않으면 뿌리가 과습으로 썩을 수 있으니 주의해야 해요  그리고 성장이 멈추는 겨울에는 흙을 건조하게 관리해주어야 합니다  ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  흙의 상태를 보면서 날씨와 계절에 따라 물주는 기간을 조절하면서 관리해주세요   물이 부족하면 줄기가 쳐진 상태로 자라서 위로 자라지 않고, 넓게 퍼질 수 있어요. 잎이 쳐지기 시작하면 물을 충분히 주어야 합니다  ⠀⠀⠀⠀ ⠀⠀⠀⠀ ☠ 천남성과에 속하는 식물이라 약간의 독성이 있기 때문에  반려동물 이 먹지않도록 주의해주시고 가지치기를 할 때 나오는 물을 직접적으로 만지지마세요   ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000295',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-12T09:13:46'},
#    'content': {'text': '[고포레스트] 오묘하면서 섹시한 잎색을 가진  콜로카시아에스쿨렌타  다이아몬드헤드   이름이 참길지요?   물토란의 일종으로 윤기나는 검정 잎이 매력적인 아이에요. 화분에 심을수도 있고 수경재배도 가능해요. 수경 버젼도 곧 보여드릴께요   ⠀⠀⠀⠀   햇빛을 무척 좋아해 양지에서 키우시길 추천드려요. 성체가되면 직사광선에도 잘 자랍니다  추위에는 약한편이고 적정 생육온도는 15 20도 이상입니다. ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀   물을 좋아해 흙은 항상 촉촉하게 유지해주거나 화분의 3분 2정도까지 물에 담가 저면관수로 키우셔도 됩니다. ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀⠀ ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000296',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-12T03:46:37'},
#    'content': {'text': '[고포레스트] ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ 싱그러운  무늬싱고니움 오늘 새로 입고되었어요  예쁜 화분에 빨리 식재해줘야겠어요   ⠀⠀⠀ ⠀⠀⠀⠀ 일반적으로 싱고니움은 덩굴성 식물인데 무늬싱고니움 경우 덩굴성은 조금 덜 하고 키는 더 크게 자라는 특징이 있어요. 공기정화도 잘하는 기특한 녀석이랍니다. ⠀ ⠀⠀⠀  무늬싱고니움 키우기Tip ⠀ ⠀⠀⠀ ⠀⠀⠀⠀   강한 햇빛에 오래 노출되면 잎가장자리가 손상을 입을 수 있으니 반양지에서 키우시는걸 추천드려요  (생육온도 15 25도) ⠀⠀⠀ ⠀⠀⠀ ⠀⠀⠀⠀ ⠀  물주기는 계절따라 차이가 있지만 기온이 오르는 봄부터 여름에는 겉흙이 마르면 흠뻑 주시고, 기온이 낮아지는 늦가을부터 겨울은 흙 상태를 살펴보며 아주 바싹 말랐을 때 흠뻑 줍니다 . 실내가 건조하다면 잎에 분무를 해 주면 더 좋습니다. ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000297',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-11T15:09:02'},
#    'content': {'text': ' [고포레스트] 사막의 야자수   라메리 마치 가시달린 파인애플 같기도 합니다    선인장  답지않게 싱그러운 잎이 너무나도 사랑스러워요  양지, 반양지에서 키우기 적합하며 물주기는 한달에 한번 정도 흙이 바싹 마르면 주시면됩니다. (장마철, 겨울엔 단수를 해주어도건강하게 잘 자랍니다.) ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ 무심한듯 키워주세요    ⠀ ⠀⠀⠀⠀ ⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀ ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000298',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-09T13:19:03'},
#    'content': {'text': '[고포레스트] 멋스러운 목대와 은빛의 화려한 한송이 꽃같은    아가베 아가베가 있는 공간은 마법을 부린듯 너무나 사랑스러워지는것 같아요  키우기가 까다롭지않아 인테리어,  반려식물 로 추천드립니다. ⠀⠀⠀⠀ ⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000299',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-09T12:40:47'},
#    'content': {'text': '[고포레스트] 고급스럽고 세련된 공간을 만들고싶다면  여인초 만한게 없죠   새로 오픈한 카페 사장님께서 직접 저희 매장에 방문, 공간에 어울리는 식물을 추천받으시고 선택하셨어요   2.2m 높이의 풍성한 대형 여인초는 카페 분위기와 정말 잘 어울리네요  ⠀⠀⠀⠀ ⠀  여인초의 여인은 흔히 부드러운 곡선으로 자라나는 모양으로 인해 여성을 뜻한다고 생각하지만 사실은 ‘여행자’ 라는 의미랍니다. 여인초의 넓은 잎을 통해 모인 빗물을 목마른 여행자들이 줄기에 구멍을 뚫어 목을 축이던 것에서 유래한 이름이예요.   비교적 음지에 강하고 습도 조절 공기 정화 효과 역시 탁월하고 실내에서 기르기 쉬워 가정, 사무실 모두 추천드리는 식물 입니다. ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000300',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-08T15:21:19'},
#    'content': {'text': '[고포레스트] 이곳은 회사사무실 이전을 하면서 식물을 문의를 해주신 사무실입니다. 독특한 구조의 공간을 갖고 있어 공간 컨디션에 맞는 식물을 추천드리고 배치후 직접 방문하여 관리방법도 전수해드렸습니다   특히 3m 높이의 대형  떡갈고무나무 는 너무 잘 어울리고 예쁘네요 ❤ 사실 집보다 더 오래머무는 공간이 바로 사무실.. 파티션으로 꽉막힌 사무실에도 힐링할수 있는 작은숲이  있다면 얼마나 좋게요   ⠀⠀⠀⠀⠀⠀ ⠀⠀⠀ ⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀ ⠀⠀⠀⠀⠀⠀ ⠀⠀'}}},
#  {'id': 'IPRW2100000301',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-08T10:37:11'},
#    'content': {'text': '[고포레스트] 너무나 예쁜 스튜디오( greohada_part1)로 가서 호강하고있는  덕구리난 (독구리난) 호리병같은 몸매에 야자수인냥 뽐내며 분수모양 긴잎이 매력적인 나무예요   멕시코 사막지대에 사는 식물답게 건조한 환경에도 강하고 1000년 넘게 살수 있다고 하니  반려식물 로 딱   (키우기 참 쉽답니다 ㅋ) ⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀ ⠀⠀⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀⠀⠀'}}},
#  {'id': 'IPRW2100000302',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-08T07:43:59'},
#    'content': {'text': '[고포레스트]  한옥집  남천 그리고  관음죽 한옥집은 게스트하우스로 운영되는 곳이라 관리가 쉬운 나무를 문의하셨는데 현장 답사를 가본 결과 한옥집 안쪽은 해가 잘 들지않아 그늘에서도 잘 사는  관음죽을 외부 정원에는  남천나무를 추천 드렸습니다. ⠀⠀ ⠀⠀  남천나무는 겨울에도 월동이 되는 나무로 액군을 막아준다하여 정원수로 많이 심습니다. 또한 꽃, 열매, 가을엔 단풍까지 보실수 있는 운치있고 매력적인 나무입니다. 한옥집과 정말 잘 어울렸어요   ⠀⠀⠀ 예전엔 정원수로만 많이 심으셨데 요즘 센스있는 카페나 가정에서도 많이 구매하신답니다.   ⠀ ⠀ ⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀ ⠀⠀⠀ ⠀⠀'}}},
#  {'id': 'IPRW2100000303',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-08T07:06:16'},
#    'content': {'text': '[고포레스트]  광고 에 출연한  겐차야자   디렉터님이 섹시한 느낌의 나무를 찾으셨는데   잎 라인이 섹시한 겐차로 pick   고급스럽고 이국적인 느낌으로 반그늘에서도 강해 인테리어 식물로 강력추천 드려요  요즘 가격도 많이 착해졌답니다  ⠀⠀ ⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀ ⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀ ⠀'}}},
#  {'id': 'IPRW2100000304',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-07T09:10:49'},
#    'content': {'text': '[고포레스트] 이국적인 인테리어가 필요하다면 야자   만한게 없죠   ⠀ 2m 높이의 대형  피닉스야자  도시로야자 매장 분위기와 너무나 잘 어울려 구매한 고객님이 정말 만족해하셨어요    ⠀  토분  빈티지토분 ⠀ ⠀ ⠀⠀ ⠀⠀ ⠀⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀ ⠀⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다. ⠀'}}},
#  {'id': 'IPRW2100000305',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-07T07:47:02'},
#    'content': {'text': '[고포레스트]  올리브 는 풍요와 번영, 평화를 상징하는 나무입니다. ⠀ 가정과 매장 인테리어 식물로도 많이 나가지만 요즘  센스있는 분들은 영전,  승진선물 로도 많이 보내는 나무입니다.   ⠀⠀ ⠀  지중해  그리스풍  빈티지  토분 ⠀⠀ ⠀⠀ ⠀⠀ ⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀⠀ ⠀  식물문의는 프로필 상단 카톡(고포레스트)으로 부탁드립니다.'}}},
#  {'id': 'IPRW2100000306',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-07T06:46:51'},
#    'content': {'text': '[고포레스트] 동글동글 물방울모양의 잎이 매력적인  유칼립투스폴리안 ⠀ 유칼립투스는 그리스어의 ‘아름답다’와 ‘덮인다’의 합성어로 오래전부터 많은 사랑을 받아온 나무예요. ⠀ 유칼립투스 잎의 오일은 특유의 상쾌한 향기와 함께 강한 살균 효과가 있어 약용으로도 많이 사용되고 있답니다  ⠀ 햇빛과 통풍이 좋은곳에서 키우시면 예쁘게 잘 자란답니다   ⠀⠀ ⠀  지친 일상을 위로해주는 나만의 작은숲  식물을 키우며 마음을 정화해보세요  ⠀ ⠀  식물문의는 프로필 카톡으로 부탁드립니다. (댓글과 DM으로는 문의를 받지않아요     ) ⠀ ⠀'}}},
#  {'id': 'IPRW2100000307',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-01T08:06:34'},
#    'content': {'text': ' 식물과 함께하고 싶으세요? 고포레스트는 당신의 환경에 맞는 나무와 스타일을 제안해드립니다 ; )  식물소통'}}},
#  {'id': 'IPRW2100000308',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-10-01T07:13:33'},
#    'content': {'text': "고포레스트  ⠀⠀⠀ ⠀ ⠀ 오지캠핑이 취미였던 저희는 숲에서 가장 행복했고 자연에서 가장 편안했습니다. 각자 콘서트 기획자와 이벤트 기획자로 다니던 회사를 그만두고 나무 그늘 아래서 풀벌레 소리를 들으며 잠들고, 아침이면 싱그러운 숲의 향기를 맡으며 일어나는 자연이 주는 그 행복감을 여러분에게 전하고 싶어 '고포레스트'는 시작되었습니다.      ⠀ ⠀"}}},
#  {'id': 'IPRW2100000309',
#   'metadata': {'title': '휘뚜마뚜 웹문서 말뭉치 IPRW21',
#    'creator': '이재관',
#    'distributor': '휘뚜마뚜',
#    'year': '2021',
#    'category': '인스타그램 > 식물',
#    'annotation_level': ['원시'],
#    'sampling': '텍스트 추출'},
#   'document': {'metadata': {'title': '무제',
#     'author': 'goforest.365',
#     'date': '2019-01-09T16:50:57'},
#    'content': {'text': '식물, 자연과 함께하는 삶. 여러분도 지금 시작해보세요    Welcome to the forest  goforest ⠀⠀⠀⠀ ⠀⠀'}}}]

# %%
# 폴더 경로 설정 및 json 파일로 저장.
with open('c:\IG\IP1.json', 'w') as f:
    json.dump(insta_dict, f,indent=4)

# %%
#json 파일 로드
with open('c:\IG\sample.json','r') as f:
    json_file=json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4a88dd7c7704> in <module>
# ----> 1 with open('c:\IG\sample.json','r') as f:
#       2     json_file=json.load(f)
#       3
#       4 print(json_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\IG\\sample.json'

# %%
'''예시 아래 결과창'''

import pandas as pd
from selenium.webdriver.common.keys import Keys
def crawl(self):
    insta_dict = {'img':[],
                    'id':[],
                  'date': [],
                  'like': [],
                  'text': [],
                  'hashtag':[]}
    ## 이미지 수집

    try:
        srcs=driver.find_element_by_xpath('/html/body/div[6]/div[2]/div/article/div/div[1]/div/div/div/div/div/video')
        src=srcs.get_attribute('poster')
        insta_dirct['img'].append(src)
    except:
        src=driver.find_element_by_xpath('/html/body/div[6]/div[2]/div/article/div/div[1]/div/div[1]/div[2]/div/div/div/ul/li/div/div/div/div/img')
        src=src.get_attribute('src')
        insta_dict['img'].append(src)
    ## id 정보 수집
    try:
        info_id = driver.find_element_by_css_selector('h2._6lAjh').text
        insta_dict['id'].append(info_id)
    except:
        info_id = driver.find_element_by_css_selector('div.C4VMK').text.split()[0]
        insta_dict['id'].append(info_id)
    print(insta_dict['id'])
    print()


    ## 시간정보 수집 
    upload_time=driver.find_element_by_xpath('/html/body/div[6]/div[2]/div/article/div/div[2]/div/div[2]/div[2]/a/time')
    print(upload_time.get_attribute('title'))
    time_raw = driver.find_element_by_css_selector('time.FH9sR.Nzb55')
    time_info = pd.to_datetime(time_raw.get_attribute('datetime')).normalize()
    insta_dict['date'].append(time_info)
    print(insta_dict['date'])
    print()

    ## like 정보 수집
    try:
        check=driver.find_element_by_xpath('/html/body/div[6]/div[2]/div/article/div/div[2]/div/div[2]/section[2]/div/span/span')
        
    except:
        try:
            like=driver.find_element_by_xpath('/html/body/div[6]/div[2]/div/article/div/div[2]/div/div[2]/section[2]/div/div/a/span')
            insta_dict['like'].append(like)
            
        except:
            id=[]
            driver.find_element_by_xpath('/html/body/div[6]/div[2]/div/article/div/div[2]/div/div[2]/section[2]/div/div[2]/a[2]').click()
            while True:
                last_height =driver.find_element_by_xpath('/html/body/div[7]/div/div/div[3]/div/div/div/div/div/div/span/a').location

                c=driver.find_elements_by_xpath('/html/body/div[7]/div/div/div[3]/div/div/div/div/div/div/span/a')

                for i in c:  
                    if i.text not in id:
                        id.append(i.text)     
                    else:
                        pass
                
                driver.find_element_by_css_selector('div._1XyCr').click()
                driver.find_element_by_css_selector('body').send_keys(Keys.PAGE_DOWN)
                driver.find_element_by_css_selector('body').send_keys(Keys.PAGE_DOWN)
                driver.find_element_by_css_selector('body').send_keys(Keys.PAGE_DOWN)
                time.sleep(1)
                new_height =driver.find_element_by_xpath('/html/body/div[7]/div/div/div[3]/div/div/div/div/div/div/span/a').location

                if last_height==new_height:
                    driver.find_element_by_xpath('/html/body/div[7]/div/div/div[1]/div/div[2]/button').click()
                    break

            like=len(id)
            insta_dict['like'].append(like)

    ##text 정보수집
    raw_info = driver.find_element_by_css_selector('div.C4VMK').text.split()
    raw_info = raw_info[1:len(raw_info)-1]
    text=[]
    for i in raw_info:
        if '#' in i:
            pass
        else:
            text.append(i)
    clean_text = ' '.join(text)
    text.append(clean_text)
    insta_dict['text'].append(text)



    ##hashtag 수집
    raw_tags = driver.find_elements_by_css_selector('a.xil3i')
    hash_tag = []
    for i in raw_tags:
        hash_tag.append(i.text)
    insta_dict['hashtag'].append(hash_tag)
# Out:
# https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/239218352_335498761650611_1251356593086644312_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=111&_nc_ohc=G78EYJ1SFPMAX_B6Pku&edm=AP_V10EBAAAA&ccb=7-4&oh=76b23c271d1ea87146c2781573ac94fe&oe=616D2144&_nc_sid=4f375e
# ['hello_storylibrary']
#
# 2021년 8월 20일
# [Timestamp('2021-08-20 00:00:00+0000', tz='UTC')]
#
# 26
#
# ["[스토리라이브러리만의 특별한 영화 추천, 스라의 빛✨소개] 🎬 너무 좋아서 벽치다가 무너져서 🎬 옆집 만날 장르?! 🎬 말이 필요없는 망작?! 🎬 꿈에 나올것 같았던 영화?! 🎬 간단하게 보기 좋은 영화?! 🎬 꿈인지 현실인지 헷갈리는 영화?! 스라러 재영이 만들어준 영화 추천 큐레이션 게시판, '스라의 빛' 반응이 핫해요! 이미 있는 영화 장르를 제외하고 새로운 장르와 장르에 어울리는 영화를 추천하는 게시판이에요. 게시판이 생긴지 한달도 되지 않아서 어느새 빼곡히 추천 장르, 영화로 가득찼어요. 하루 하루 스라러들이 슬쩍 남겨주고 간 흔적을 읽어보는 재미가 쏠쏠해요. 새로운 영화를 살펴보며 낯선 영감을 만나고 싶다면 스라로 놀러오세요! 오늘도 스토리라이브러리 문 활-짝! 저녁 6시까지 문을 열어둘께요. 9월부터는 수, 목, 금요일은 오후 5시부터 저녁 9시까지, 주말엔 오후 12시부터 6시까지 문을 열어요! 놀러오고 싶다면 프로필 링크를 클릭👆"]
#
# ['#스토리라이브러리', '#스라', '#스라러', '#스라의빛', '#영화', '#영화추천', '#장르', '#장르추천', '#1219세전용작업실', '#혜화역2번출구']

# %%
import re
a='🎬 너무 좋아서 벽치다가 무너져서 ###🎬 ####옆#집# 만날 장르?! 🎬 말이 필요없는 망작?! 🎬 꿈에 나올것 같았던 영화?! 🎬 '
b=re.sub('[\U00010000-\U0010ffff#]',' ',a)
print(b)
b.split()
# Out:
#   너무 좋아서 벽치다가 무너져서          옆 집  만날 장르?!   말이 필요없는 망작?!   꿈에 나올것 같았던 영화?!
# ['너무',
#  '좋아서',
#  '벽치다가',
#  '무너져서',
#  '옆',
#  '집',
#  '만날',
#  '장르?!',
#  '말이',
#  '필요없는',
#  '망작?!',
#  '꿈에',
#  '나올것',
#  '같았던',
#  '영화?!']
