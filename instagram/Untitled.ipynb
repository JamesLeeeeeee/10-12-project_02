# %%
import khaiii
import json
import re
import pandas as pd
import numpy as np

# %%
khaiii=khaiii.KhaiiiApi()

# %%
with open('혜화역1번출구_.json' , 'r') as f:
    insta_dict1=json.load(f)
with open('혜화역2번출구_.json' , 'r') as f:
    insta_dict2=json.load(f)
with open('혜화역3번출구_.json' , 'r') as f:
    insta_dict3=json.load(f)
with open('혜화역4번출구_.json' , 'r') as f:
    insta_dict4=json.load(f)
with open('혜화역출구전체_.json' , 'r') as f:
    insta_dict=json.load(f)

# %%
#정규식으로 불필요한 문자 제거
newtexts = ''
for texts in insta_dict2['text']:
    for text in texts:
        text = re.sub('[0-9]+', '', text)
        text = re.sub('[A-Za-z]+', '', text)
        newtext = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ·!』\\‘’|\(\)\[\]\<\>`\'…》]', '', text)
        newtexts += newtext

# %%
l=[]
a= ['우리나라 아동들을 돕는 찬스팔찌']
for j in a:
    b= khaiii.analyze(j)
    for i in b:
        try:
            for j in i.morphs:
                if j.tag=='NNG' or j.tag=='NNP':
                    l.append(j.lex)
                    print(j.lex)
        except:
            pass
print(l)
l
# Out:
# 우리나라
# 아동
# 찬스팔
# 찌
# ['우리나라', '아동', '찬스팔', '찌']

# %%
insta_dicts=[insta_dict1, insta_dict2, insta_dict3, insta_dict4]
list1=[]
list2=[]
list3=[]
list4=[]

like= []
for i in likes:
    numbers = re.sub(r'[^0-9]', '', i)
    if numbers == '':
        like.append(0)
    else:
        like.append(int(numbers))
        
for q in insta_dicts:    
    
    for w in range(len(q['id'])):
        
        digit=str(q['like'][w])
        digit=digit.replace('[^0-9]','')
        print(digit)
       
#         form=[q['id'][w],q['like'][w],q['text'][w],q['hashtag'][w]]
#     if q==insta_dict1:
#         list1.append(form)
#     elif q==insta_dict2:
#         list2.append(form)
#     elif q==insta_dict3:
#         list3.append(form)
#     elif q==insta_dict4:
#         list4.append(form)
# Out:
# 32
#
# 37
#
# 155
#
# 189
#
# 105
#
# 72
#
# 30
#
# 243
#
# 76
#
# 6
#
# 24
#
# 37
#
# 43
#
# 13
#
# 41
#
# 11
#
# 189
#
# 16
#
# 15
#
# 9
#
# 11
#
# 11
#
# 16
#
# 36
#
# 11
#
# 35
#
# 9
#
# 19
#
# 10
#
# 8
#
# 19
#
# 9
#
# 129
#
# 68
#
# 9
#
# 72
#
# 14
#
# 55
#
# 75
#
# 71
#
# 25
#
# 66
#
# 103
#
# 5
#
# 10
#
# 81
#
# 12
#
# 8
#
# 9
#
# 5
#
# 35
#
# 26
#
# 44
#
# 64
#
# 60
#
# 32
#
# 105
#
# 41
#
# 48
#
# 62
#
# 60
#
# 52
#
# 13
#
# 35
#
# 13
#
# 10
#
# 28
#
# 161
#
# 25
#
# 60
#
# 101
#
# 18
#
# 154
#
# 2
#
# 12
#
# 44
#
# 14
#
# 22
#
# 108
#
# 37
#
# 40
#
# 38
#
# 18
#
# 85
#
# 41
#
# 11
#
# 7
#
# 3
#
# 288
#
# 47
#
# 8
#
# 43
#
# 292
#
# 80
#
# 41
#
# 30
#
# 87
#
# 9
#
# 124
#
# 93
#
# 90
#
# 28
#
# 15
#
# 147
#
# 8
#
# 23
#
# 19
#
# 11
#
# 18
#
# 79
#
# 55
#
# 22
#
# 66
#
# 17
#
# 35
#
# 8
#
# 35
#
# 22
#
# 53
#
# 57
#
# 84
#
# 16
#
# 14
#
# 168
#
# 3
#
# 65
#
# 54
#
# 10
#
# 60
#
# 71
#
# 59
#
# 1
#
# 85
#
# 89
#
# 97
#
# 74
#
# 46
#
# 68
#
# 39
#
# 56
#
# 64
#
# 140
#
# 54
#
# ...

# %%
a=b
c=b
# Out:
# 3 3
