# %%
#필요한 라이브러리
import pandas as pd
from fake_useragent import UserAgent #봇이 아닌 유저라는 걸 알려주기위한 가짜유저만듦
from selenium import webdriver #webdriver로 Chrome홈페이지 연결
from selenium.webdriver.chrome.options import Options #WebDriver를 Browser 없이 실행하기 위한 모듈
from selenium.webdriver.common.by import By #By로 html속성 '값'으로 요소찾음
from selenium.webdriver.support import expected_conditions as EC #특정 html코드가 존재하는지 여부체크
from selenium.webdriver.support.ui import WebDriverWait #EC가 뜰때까지 기다림
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import TimeoutException #EC에서 설정한 시간이 지나면 뜨는 에러 exception처리
import json
import time
import urllib.request #이미지 저장
from selenium.webdriver.common.keys import Keys #스크롤다운
from bs4 import BeautifulSoup
import insta_craw #인스타 크롤링 모듈

class IG_Bot:
    """Creating a Bot"""
    def __init__(self, username, password):
        #randomized User ID
        ua = UserAgent()
        user_agent = ua.random
        options = Options()
        #"--headless" => WebDriver를 Browser 없이 실행하는 옵션.
        #chrome_option,add_argument("--headless")
        #리눅스 서버와 같이 GUI를 제공하지 않는 환경일 시 아래 두코드 필요.
        options.add_argument("--no-sandbox")
        options.add_argument("--disable_gpu") #gou 끄기
        options.add_argument(f"user_agent={user_agent}") # useragent값
        path = r'C:\Users\user\프로젝트A_Instagram\chromedriver_win32\chromedriver.exe'
        cookies_file_path = 'cookies.json'
        cookie_websites = ['https://Instagram.com']
        self.cookies_file_path = cookies_file_path
        self.cookie_websites = cookie_websites
        self.driver = webdriver.Chrome(executable_path=path, chrome_options=options)
        self.driver.get('https://Instagram.com')
        time.sleep(2)
        #save_cookie가 되어있을 때
        try:
            #Load in cookies for the website
            cookies = json.load(open(self.cookies_file_path, 'rb'))
            for website in self.cookie_websites:
                for cookie in cookies:
                    self.driver.add_cookie(cookie)
                self.driver.refresh()
        except Exception as e:
            print(str(e))
            print("Error Loading in Cookies")
            
    
    #쿠키 저장함수
    def save_cookie(self):
        """Save Cookie"""
        json.dump(self.driver.get_cookies(), open("cookies.json", 'w'))
    
    #쿠키 불러오는 함수
    def load_cookie(self):
        """Load Cookie into browser"""
        cookies = json.load(open('cookies.json', 'rd'))
        for cookie in cookies:
            self.driver.add_cookie(cookie)
    
    #로그인 함수
    def login(self):
        """Login to Instagram"""
        try:
            #저장 쿠기 없을 시
            self.username = username
            self.password = password
            WebDriverWait(self.driver, 5).until(EC.presence_of_element_located((By.XPATH, '//*[@id="loginForm"]/div/div[1]/div/label/input')))
            self.driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[1]/div/label/input').send_keys(username)
            time.sleep(1)
            self.driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[2]/div/label/input').send_keys(password)
            time.sleep(1)
            self.driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[3]/button/div').click()
            try:
                WebDriverWait(self.driver, 3).until(EC.presence_of_element_located((By.XPATH, '//*[@id="react-root"]/section/main/div/div/div/div/button')))
            except TimeoutException:
                pass
            else:
                self.driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/div/div/button').click()
            try:
                WebDriverWait(self.driver, 3).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[5]/div/div/div/div[3]/button[2]')))
            except TimeoutException:
                pass
            else:
                self.driver.find_element_by_xpath('/html/body/div[5]/div/div/div/div[3]/button[2]').click()
        except:
            #저장 쿠기 있을 시
            try:
                WebDriverWait(self.driver, 3).until(EC.presence_of_element_located((By.XPATH, '/html/body/div[5]/div/div/div/div[3]/button[2]')))
            except TimeoutException:
                pass
            else:
                self.driver.find_element_by_xpath('/html/body/div[5]/div/div/div/div[3]/button[2]').click()
    def run(self):
        insta_craw.IG_run(self.driver)

        
if __name__ == '__main__':
    """Main (runs the classes/functions)"""
    data=pd.read_csv('secret.txt',header=None)
    username=data.iloc[0][0]
    password=data.iloc[1][0]
    
    #IG_BOT실행
    bot = IG_Bot(username, password)
    bot.login()
    #cookie 저장하기
    bot.save_cookie()
    bot.run()
# Out:
# <ipython-input-1-366c326b6c37>:36: DeprecationWarning: use options instead of chrome_options
#   self.driver = webdriver.Chrome(executable_path=path, chrome_options=options)
# 검색어 입력 > 혜화역2번출구
# 게시글: 1
# the_side_table
# 함박웃음식당
# ['🧐 어랏? 오늘은 쟤네 뭘먹지? - 대학로 추억여행 왔어요(구 대학로 직장인). 여긴 점심시간에 사케동 먹으러 자주 오던 곳이에요. 사케동이 7900원이라 가성비 좋게 먹기 좋은 곳이에요! 간장 살짝 묻혀 생와사비 얹어서 먹으면... 말모..? 입안에서 톡톡 터지는 날치알과 함께 먹어도 좋네유😋 (점심 먹고 낙산공원 한바퀴 산책하면 완벽!!) - 📍함박웃음식당 : 서울 종로구 동숭길 51 🍴추천메뉴 : 사케동(일반/곱빼기), 아보카도치즈함박스테이크']
# ['#궁금한_옆테이블', '#함박웃음식당']
# 좋아요 222개
# 2020-03-31T02:46:56
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/91774043_1491158751066324_5811170485347168568_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=100&_nc_ohc=aEOuvoeF8T4AX_Daq0-&edm=AP_V10EBAAAA&ccb=7-4&oh=688625b3eed08b49179e92a046ab77e4&oe=617F9606&_nc_sid=4f375e
# 게시글: 2
# eva__ham
# 장소정보가 없습니다.
# ['여성을 죽이는 범죄, 여성이기 때문에 겪는 일로 죽게 되는 범죄까지 페미사이드라고 한다. 메세지는 간단하다. 페미사이드 그만하자는 것이다. 심플! 모두 같은 생각 아닌가요? _ 여성들이 왜 스스로 자살을 선택하게 될까? 멘탈이 약해서? 아니다. _ 나를 보호할 제도와 법이 없고 사회적 분위기마저 그렇기 때문이다. 가까운 사람으로부터의 데이트폭력, 가정폭력, 강간, 각종 성희롱, 성취행에 속하는 성범죄, 불법촬영 등 디지털성범죄, 스토킹, 여성혐오, 여성성적대상화, 가스라이팅, 사이버불링, 사진 지인능욕 등 결국 그냥 모두 혼자서 감당해야 한다는 것을 알게 되면서 무기력함이 오고 우울증이오고 결국엔 그 굴레를 끊어버리는 것으로 자살말고는 선택할게 없기 때문에 선택한다. 그것이 과연 선택일까? 우리 사회는 책임이 없을까? 이대로 베르테르 효과 취급하고 조용하면 될까? 정말 여성들이 무엇이든 안전하고 자유롭게 무엇이든 할 수 있는 환경일까? 현실이 이러니까 조심이야 해야겠지만 조심만 해서 될까? 얼마나 더 조심해야할까? 그래서 그거 하지말라고 여성 대상으로 범죄 그만하라고 모이는 날이다. _ 나 역시 여러번의 구체적인 자살을 생각했었고 단지 여러가지로 운이 좋아서 살았다. 살고 싶어서 자살을 선택하는 아이러니를 나는 안다. 나는 그럼 삶의 의지가 없고 부족한 약한 타입일까? 이건 지인들이 더 잘 알거라 믿는다. _ 여성 상대 살인, 강간, 폭력 역시 뉴스, 영화, 드라마, 소설, 뮤지컬 그냥 픽션, 논픽션 할 것 없이 마구 쏟아지는 흥미로운 이슈꺼리 콘텐츠가 되어버렸다. 그렇게 사람들은 무뎌졌다. 하지만 이제 여성 피해자를 만들지말고 보호해야한다고 말해야한다. _']
# ['#여성대상범죄그만합시다', '#여자그만죽입시다', '#페미사이드철폐시위', '#혜화역', '#여성대상범죄', '#femicides', '#femicide', '#페미사이드', '#페미사이드철폐', '#마로니에공원', '#혜화역2번출구', '#stopfeminicides', '#stopfemicide', '#혜화역시위']
# 좋아요 123개
# 2019-12-28T05:38:25
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/81152591_2373474952963305_7722438612312477742_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=109&_nc_ohc=wPA2RwCqA_cAX8hHumN&edm=AP_V10EBAAAA&ccb=7-4&oh=c33fae9b8443b69989bfac0db5b737ac&oe=617F12BE&_nc_sid=4f375e
# 게시글: 3
# eunkyung.choi79
# 장소정보가 없습니다.
# ['울 아드님 몇일전부터 혜화동 2번 출구를 외쳐대서... 함 가봤지! 와~ 달고나가 이렇게 인기!! 오징어게임 대단하네~ 1시간 기다려 도전했지만 실패!! 그래도 넘 잼있었다는 아드님! 아~~~ 대학로~~~~ 난 아드님 때문에 옛 추억 새록새록!! 이었네! . .']
# ['#오징어게임', '#달고나달인👍', '#혜화역2번출구', '#마로니에공원', '#20년전으로돌아간기분', '#추억소환', '#초딩맘일상', '#휴일스타그램']
# 좋아요 78개
# 2021-10-24T06:40:17
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/248286037_852718738757064_6639677425120125419_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=100&_nc_ohc=nJZc8u-m4bsAX-UVqXC&tn=Xi5OdicqzorLVr0n&edm=AP_V10EBAAAA&ccb=7-4&oh=0c2cb8d22aed17659b0194d569d11c51&oe=617F2A5A&_nc_sid=4f375e
# 게시글: 4
# narehuwj19
# 장소정보가 없습니다.
# ['동생주려고 삼']
# ['#오징어게임', '#달고나', '#오징어게임달고나집', '#우산달고나', '#네모달고나', '#학교근처', '#한개에', '#3000원', '#ㅎㅋㅎㅋ#혜화역2번출구#뽑기의신']
# 좋아요 17개
# 2021-10-06T07:59:00
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/244443206_626950988475286_2360132167239821278_n.webp.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=110&_nc_ohc=fxN4YKmema0AX-WyAYI&edm=AP_V10EBAAAA&ccb=7-4&oh=1ba195849775854957b5ab4a91924977&oe=617F76C8&_nc_sid=4f375e
# 게시글: 5
# yerin_rinirini
# 장소정보가 없습니다.
# ['준아 잘보내구 @actor.k_daewoo @kchanghyun @kim.borim']
# ['#오늘의연극', '#연극', '#작업의정석', '#우리', '#커튼콜', '#뿌잉뿌잉', '고마와용!😘👍#주말', '#다음주에', '#또만나요', '#🙊', '#서민준', '#멀티남', '#멀티녀', '#공연스타그램', '#연극추천', '#데이트코스', '#꿀잼', '#대학로', '#혜화역2번출구', '#순위아트홀', '#보러와요', '#❤']
# 조회 1,416회
# 2017-04-21T14:54:03
# 사진정보가 없습니다.
# 게시글: 6
# woodry_jung
# 장소정보가 없습니다.
# ['에 달고나 납품한 집이래요 앞에 팔아요 매우 두껍고 튼튼해진 상업적인 달고나. 너무 어렵네. 살기는 쉽지 않겠다. 저중에 있으니 우산이 젤 쉬워 보임 ㅎㅎ .']
# ['#대학로달고나', '#오징어게임', '#혜화역2번출구', '#오징어게임달고나', '#대학로', '#혜화']
# 좋아요 38개
# 2021-10-11T01:21:05
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/245043837_406296774407570_9035314274954315299_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=102&_nc_ohc=RuKLFwvDWYkAX-ueSgR&edm=AP_V10EBAAAA&ccb=7-4&oh=078d59d85228214f0c59ed6aa8f47143&oe=617F13E4&_nc_sid=4f375e
# 게시글: 7
# minjinchoa
# 장소정보가 없습니다.
# ['인증됨']
# ['#크레용팝#초아#허민진#뮤지컬#덕혜옹주#대학로#혜화역2번출구#어젯밤#길가다나발견', 'None']
# 좋아요 2,434개
# 2015-04-02T07:12:22
# 사진정보가 없습니다.
# 게시글: 8
# masterkidscooking
# 장소정보가 없습니다.
# ['. 늦은 1월메뉴 공지 입니다 . 오픈 초, 회원님들이 마키쿠를 잘 알지 못할때, 그래서 많이 만나뵙지 못했던 메뉴를, 꺼내어 봅니다. . 이런저런 메뉴들에대한 요청이 많았지만, 최근 메뉴들은 하반기에 한번더 앵콜로, 이렇게 상반기/하반기 한번씩 앵콜을 진행해보려합니다 . . 그때보다, 좀 더 업그레이드 되어서, 좀 더 보완해서, 나오게 되겠지요 . . 1월에도, 쭉 만나요 마키쿠는, 사랑입니다^^ . . .']
# ['#크로와상', '#크로와상샌드위치', '#티라미수', '#딸기티라미수', '#리코타치즈샐러드피자', '#떡갈비', '#마스터키즈쿠킹#키즈쿠킹#키즈베이킹#유아쿠킹클래스#아동요리교실#푸드테라피#편식개선#야채놀이#문화센터#방과후수업#원데이클래스#업데이트#엄마휴식#머랭쿠키#타마고산도#종로체험#혜화역2번출구#네이버예약가능#육아스타그램#기업특강#유치원단체']
# 좋아요 38개
# 2019-12-27T22:13:54
# https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/78904488_855156688232315_2290389968182957171_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=111&_nc_ohc=_8BBgIEkFy8AX_ddPIM&tn=Xi5OdicqzorLVr0n&edm=AP_V10EBAAAA&ccb=7-4&oh=673b437b08ab0f50f40e619753dc14ad&oe=6180EF36&_nc_sid=4f375e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-366c326b6c37> in <module>
#     110     #cookie 저장하기
#     111     bot.save_cookie()
# --> 112     bot.run()
#
# <ipython-input-1-366c326b6c37> in run(self)
#      96                 self.driver.find_element_by_xpath('/html/body/div[5]/div/div/div/div[3]/button[2]').click()
#      97     def run(self):
# ---> 98         insta_craw.IG_run(self.driver)
#      99
#     100
#
# ~\프로젝트A_Instagram\2조_Instagram\1.소스코드\insta_craw.py in IG_run(driver)
#      57                 no += 1
#      58                 #다음 게시글 클릭
# ---> 59                 time.sleep(1+ random.randrange(1,7))
#      60             try:
#      61         #         driver.find_element_by_xpath('/html/body/div[6]/div[1]/div/div/div[2]').click()
#
# KeyboardInterrupt:

# %%
import json
#Load in cookie
data = json.load(open('instagram_data.json', 'rb'))
print(data)
# Out:
# {'id': ['the_side_table', 'eva__ham', 'eunkyung.choi79', 'narehuwj19', 'yerin_rinirini', 'woodry_jung', 'minjinchoa', 'masterkidscooking'], 'location': ['함박웃음식당', 'None', 'None', 'None', 'None', 'None', 'None', 'None'], 'date': ['2020-03-31T02:46:56', '2019-12-28T05:38:25', '2021-10-24T06:40:17', '2021-10-06T07:59:00', '2017-04-21T14:54:03', '2021-10-11T01:21:05', '2015-04-02T07:12:22', '2019-12-27T22:13:54'], 'like': ['좋아요 222개', '좋아요 123개', '좋아요 78개', '좋아요 17개', '조회 1,416회', '좋아요 38개', '좋아요 2,434개', '좋아요 38개'], 'text': [['🧐 어랏? 오늘은 쟤네 뭘먹지? - 대학로 추억여행 왔어요(구 대학로 직장인). 여긴 점심시간에 사케동 먹으러 자주 오던 곳이에요. 사케동이 7900원이라 가성비 좋게 먹기 좋은 곳이에요! 간장 살짝 묻혀 생와사비 얹어서 먹으면... 말모..? 입안에서 톡톡 터지는 날치알과 함께 먹어도 좋네유😋 (점심 먹고 낙산공원 한바퀴 산책하면 완벽!!) - 📍함박웃음식당 : 서울 종로구 동숭길 51 🍴추천메뉴 : 사케동(일반/곱빼기), 아보카도치즈함박스테이크'], ['여성을 죽이는 범죄, 여성이기 때문에 겪는 일로 죽게 되는 범죄까지 페미사이드라고 한다. 메세지는 간단하다. 페미사이드 그만하자는 것이다. 심플! 모두 같은 생각 아닌가요? _ 여성들이 왜 스스로 자살을 선택하게 될까? 멘탈이 약해서? 아니다. _ 나를 보호할 제도와 법이 없고 사회적 분위기마저 그렇기 때문이다. 가까운 사람으로부터의 데이트폭력, 가정폭력, 강간, 각종 성희롱, 성취행에 속하는 성범죄, 불법촬영 등 디지털성범죄, 스토킹, 여성혐오, 여성성적대상화, 가스라이팅, 사이버불링, 사진 지인능욕 등 결국 그냥 모두 혼자서 감당해야 한다는 것을 알게 되면서 무기력함이 오고 우울증이오고 결국엔 그 굴레를 끊어버리는 것으로 자살말고는 선택할게 없기 때문에 선택한다. 그것이 과연 선택일까? 우리 사회는 책임이 없을까? 이대로 베르테르 효과 취급하고 조용하면 될까? 정말 여성들이 무엇이든 안전하고 자유롭게 무엇이든 할 수 있는 환경일까? 현실이 이러니까 조심이야 해야겠지만 조심만 해서 될까? 얼마나 더 조심해야할까? 그래서 그거 하지말라고 여성 대상으로 범죄 그만하라고 모이는 날이다. _ 나 역시 여러번의 구체적인 자살을 생각했었고 단지 여러가지로 운이 좋아서 살았다. 살고 싶어서 자살을 선택하는 아이러니를 나는 안다. 나는 그럼 삶의 의지가 없고 부족한 약한 타입일까? 이건 지인들이 더 잘 알거라 믿는다. _ 여성 상대 살인, 강간, 폭력 역시 뉴스, 영화, 드라마, 소설, 뮤지컬 그냥 픽션, 논픽션 할 것 없이 마구 쏟아지는 흥미로운 이슈꺼리 콘텐츠가 되어버렸다. 그렇게 사람들은 무뎌졌다. 하지만 이제 여성 피해자를 만들지말고 보호해야한다고 말해야한다. _'], ['울 아드님 몇일전부터 혜화동 2번 출구를 외쳐대서... 함 가봤지! 와~ 달고나가 이렇게 인기!! 오징어게임 대단하네~ 1시간 기다려 도전했지만 실패!! 그래도 넘 잼있었다는 아드님! 아~~~ 대학로~~~~ 난 아드님 때문에 옛 추억 새록새록!! 이었네! . .'], ['동생주려고 삼'], ['준아 잘보내구 @actor.k_daewoo @kchanghyun @kim.borim'], ['에 달고나 납품한 집이래요 앞에 팔아요 매우 두껍고 튼튼해진 상업적인 달고나. 너무 어렵네. 살기는 쉽지 않겠다. 저중에 있으니 우산이 젤 쉬워 보임 ㅎㅎ .'], ['인증됨'], ['. 늦은 1월메뉴 공지 입니다 . 오픈 초, 회원님들이 마키쿠를 잘 알지 못할때, 그래서 많이 만나뵙지 못했던 메뉴를, 꺼내어 봅니다. . 이런저런 메뉴들에대한 요청이 많았지만, 최근 메뉴들은 하반기에 한번더 앵콜로, 이렇게 상반기/하반기 한번씩 앵콜을 진행해보려합니다 . . 그때보다, 좀 더 업그레이드 되어서, 좀 더 보완해서, 나오게 되겠지요 . . 1월에도, 쭉 만나요 마키쿠는, 사랑입니다^^ . . .']], 'hashtag': [['#궁금한_옆테이블', '#함박웃음식당'], ['#여성대상범죄그만합시다', '#여자그만죽입시다', '#페미사이드철폐시위', '#혜화역', '#여성대상범죄', '#femicides', '#femicide', '#페미사이드', '#페미사이드철폐', '#마로니에공원', '#혜화역2번출구', '#stopfeminicides', '#stopfemicide', '#혜화역시위'], ['#오징어게임', '#달고나달인👍', '#혜화역2번출구', '#마로니에공원', '#20년전으로돌아간기분', '#추억소환', '#초딩맘일상', '#휴일스타그램'], ['#오징어게임', '#달고나', '#오징어게임달고나집', '#우산달고나', '#네모달고나', '#학교근처', '#한개에', '#3000원', '#ㅎㅋㅎㅋ#혜화역2번출구#뽑기의신'], ['#오늘의연극', '#연극', '#작업의정석', '#우리', '#커튼콜', '#뿌잉뿌잉', '고마와용!😘👍#주말', '#다음주에', '#또만나요', '#🙊', '#서민준', '#멀티남', '#멀티녀', '#공연스타그램', '#연극추천', '#데이트코스', '#꿀잼', '#대학로', '#혜화역2번출구', '#순위아트홀', '#보러와요', '#❤'], ['#대학로달고나', '#오징어게임', '#혜화역2번출구', '#오징어게임달고나', '#대학로', '#혜화'], ['#크레용팝#초아#허민진#뮤지컬#덕혜옹주#대학로#혜화역2번출구#어젯밤#길가다나발견', 'None'], ['#크로와상', '#크로와상샌드위치', '#티라미수', '#딸기티라미수', '#리코타치즈샐러드피자', '#떡갈비', '#마스터키즈쿠킹#키즈쿠킹#키즈베이킹#유아쿠킹클래스#아동요리교실#푸드테라피#편식개선#야채놀이#문화센터#방과후수업#원데이클래스#업데이트#엄마휴식#머랭쿠키#타마고산도#종로체험#혜화역2번출구#네이버예약가능#육아스타그램#기업특강#유치원단체']], 'img': ['https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/91774043_1491158751066324_5811170485347168568_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=100&_nc_ohc=aEOuvoeF8T4AX_Daq0-&edm=AP_V10EBAAAA&ccb=7-4&oh=688625b3eed08b49179e92a046ab77e4&oe=617F9606&_nc_sid=4f375e', 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/81152591_2373474952963305_7722438612312477742_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=109&_nc_ohc=wPA2RwCqA_cAX8hHumN&edm=AP_V10EBAAAA&ccb=7-4&oh=c33fae9b8443b69989bfac0db5b737ac&oe=617F12BE&_nc_sid=4f375e', 'https://scontent-ssn1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/248286037_852718738757064_6639677425120125419_n.jpg?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=100&_nc_ohc=nJZc8u-m4bsAX-UVqXC&tn=Xi5OdicqzorLVr0n&edm=AP_V10EBAAAA&ccb=7-4&oh=0c2cb8d22aed17659b0194d569d11c51&oe=617F2A5A ...

# %%
/html/body/div[6]/div[1]/div/div/div/button


/html/body/div[6]/div[1]/div/div/div[2]/button


/html/body/div[6]/div[1]/div/div/div[1]/button


/html/body/div[6]/div[1]/div/div/div/button
